# %% [markdown]
# <a href="https://colab.research.google.com/github/Maypulido/colab/blob/main/Analitica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-998b3f42-925c-4a71-8933-092855f94e7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-998b3f42-925c-4a71-8933-092855f94e7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-9b159af8c7fc> in <module>()
#       1 from google.colab import files
# ----> 2 uploaded = files.upload()
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      44   """
#      45
# ---> 46   uploaded_files = _upload_files(multiple=True)
#      47   # Mapping from original filename to filename as saved locally.
#      48   local_filenames = dict()
#
# ...

# %%
oct18 = pd.read_excel('EEFF.xlsx',sheet_name='OCT 2018', usecols= 'A,B,E')
oct19 = pd.read_excel('EEFF.xlsx', sheet_name= 'OCT 2019',skiprows=1, usecols= 'A,C,G')
dic18 = pd.read_excel('EEFF.xlsx', sheet_name= 'DIC 2018', usecols= 'B,C,F')

# %%
lista_columnas = list(oct19.columns)
lista_columnas[2] = "Saldo Final"
oct19.columns = lista_columnas

# %%
oct18["Cuenta"] = oct18["Cuenta"].astype(str)
oct18["Saldo Final"] = oct18["Saldo Final"].astype(float)

oct19["Cuenta"] = oct19["Cuenta"].astype(str)
oct19["Saldo Final"] = oct19["Saldo Final"].astype(float)

dic18["Saldo Final"] = dic18["Saldo Final"].astype(float)

# %% [markdown]
# .str.slice(start=0, stop=4)

# %%
oct18.head(5)
# Out:
#        Cuenta                          descripción   Saldo Final
# 0           1                               ACTIVO  1.309100e+08
# 1          11  EFECTIVO Y EQUIVALENTES AL EFECTIVO  1.580417e+06
# 2        1105                                 CAJA  1.073849e+05
# 3      110505                         CAJA GENERAL  1.056849e+05
# 4  1105050501                   CAJA EFECTIVO COTA  7.724977e+04

# %%
oct19 = oct19.dropna()
oct19['Cuenta']=pd.to_numeric(oct19['Cuenta'])
oct19["Cuenta"] = oct19["Cuenta"].astype(int).astype(str)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
oct19
# Out:
#          Cuenta                          Descripción   Saldo Final
# 0             1                               ACTIVO  1.983762e+08
# 1            11  EFECTIVO Y EQUIVALENTES AL EFECTIVO  1.897987e+06
# 2          1105                                 CAJA  9.541741e+04
# 3        110505                         CAJA GENERAL  9.371741e+04
# 4    1105050501                   CAJA EFECTIVO COTA  1.686681e+04
# ..          ...                                  ...           ...
# 908  6135950101        RECARGAS CLARO TIEMPO AL AIRE  4.600000e+01
# 909  6135950102              EXTENSIONES DE GARANTIA  8.756588e+05
# 910  6135950200             APLICACIONES Y SERVICIOS  5.785329e+05
# 911  6135950300              SERVICIOS PROFESIONALES  4.976760e+04
# 912  6135950400              SOLUCIONES CORPORATIVAS  8.643567e+05
#
# [913 rows x 3 columns]

# %%
oct19.head(5)
# Out:
#        Cuenta                          Descripción   Saldo Final
# 0           1                               ACTIVO  1.983762e+08
# 1          11  EFECTIVO Y EQUIVALENTES AL EFECTIVO  1.897987e+06
# 2        1105                                 CAJA  9.541741e+04
# 3      110505                         CAJA GENERAL  9.371741e+04
# 4  1105050501                   CAJA EFECTIVO COTA  1.686681e+04

# %%
dic18=dic18[dic18['Saldo Final'].notna()]
dic18['Cuenta']=pd.to_numeric(dic18['Cuenta'])
dic18["Cuenta"] = dic18["Cuenta"].astype(int).astype(str)

# %%
dic18
# Out:
#     Cuenta                    Descripción   Saldo Final
# 0     1105             CAJA EFECTIVO COTA  3.505073e+04
# 1     1105          CAJA EFECTIVO UNILAGO  2.826623e+04
# 2     1105           CAJA DE CHEQUES COTA  2.010600e+05
# 3     1105            CAJA PAGOS EN CANJE  1.176860e+02
# 4     1105                CAJA MENOR COTA  1.500000e+03
# ..     ...                            ...           ...
# 439   6135  RECARGAS CLARO TIEMPO AL AIRE  4.140000e+02
# 440   6135       APLICACIONES Y SERVICIOS  5.837013e+05
# 441   6135        SERVICIOS PROFESIONALES  2.994952e+04
# 442   6135        SOLUCIONES CORPORATIVAS  8.387577e+04
# 443     61                            NaN  3.026391e+08
#
# [444 rows x 3 columns]

# %%
dic18_tmp=dic18.groupby(['Cuenta']).sum()

# %%
dic18_tmp.reset_index(inplace=True)

# %%
dic18_tmp
# Out:
#     Cuenta   Saldo Final
# 0       11  1.848261e+06
# 1     1105  2.661946e+05
# 2     1110  1.489734e+06
# 3     1120  7.318712e+04
# 4     1125  1.914546e+04
# ..     ...           ...
# 103     54  9.199300e+04
# 104   5405  0.000000e+00
# 105   5420  9.199300e+04
# 106     61  3.026391e+08
# 107   6135  3.026391e+08
#
# [108 rows x 2 columns]

# %%
oct18=oct18[oct18['Cuenta'].str.len()==4]

# %%
oct18.reset_index(inplace=True)

# %%
oct18.drop('index',axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
oct18
# Out:
#    Cuenta                           descripción   Saldo Final
# 0    1105                                  CAJA  1.073849e+05
# 1    1110                                BANCOS  1.445734e+06
# 2    1120                     CUENTAS DE AHORRO -1.105300e+01
# 3    1125                                FONDOS  2.730894e+04
# 4    1305                              CLIENTES  4.805702e+07
# ..    ...                                   ...           ...
# 82   5315                GASTOS EXTRAORDINARIOS  7.715374e+05
# 83   5395                        DIVERSOS OTROS  2.392116e+05
# 84   5405   IMPUESTO DE RENTA Y COMPLEMENTARIOS  0.000000e+00
# 85   5405  COMERCIO AL POR MAYOR Y AL POR MENOR  0.000000e+00
# 86   6135  COMERCIO AL POR MAYOR Y AL POR MENOR  2.409812e+08
#
# [87 rows x 3 columns]

# %%
oct19=oct19[oct19['Cuenta'].str.len()==4]
oct19.reset_index(inplace=True)
oct19.drop('index',axis=1,inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
oct19
# Out:
#    Cuenta                           Descripción   Saldo Final
# 0    1105                                  CAJA  9.541741e+04
# 1    1110                                BANCOS  1.685083e+06
# 2    1120                     CUENTAS DE AHORRO  2.364988e+04
# 3    1125                                FONDOS  9.383680e+04
# 4    1305                              CLIENTES  8.357217e+07
# ..    ...                                   ...           ...
# 82   5315                GASTOS EXTRAORDINARIOS  1.029121e+06
# 83   5395                        DIVERSOS OTROS  4.046842e+05
# 84   5405   IMPUESTO DE RENTA Y COMPLEMENTARIOS  0.000000e+00
# 85   5405  COMERCIO AL POR MAYOR Y AL POR MENOR  0.000000e+00
# 86   6135  COMERCIO AL POR MAYOR Y AL POR MENOR  3.685183e+08
#
# [87 rows x 3 columns]

# %%
dfa_temp=oct19.join(oct18.set_index('Cuenta'), on='Cuenta',lsuffix='_oct19', rsuffix='oct18')

# %%
dfa_temp=dfa_temp.drop(columns='descripción')

# %%
dfa=dfa_temp.join(dic18_tmp.set_index('Cuenta'), on='Cuenta')

# %%
dfa
# Out:
#    Cuenta                           Descripción  Saldo Final_oct19  \
# 0    1105                                  CAJA       9.541741e+04
# 1    1110                                BANCOS       1.685083e+06
# 2    1120                     CUENTAS DE AHORRO       2.364988e+04
# 3    1125                                FONDOS       9.383680e+04
# 4    1305                              CLIENTES       8.357217e+07
# ..    ...                                   ...                ...
# 84   5405   IMPUESTO DE RENTA Y COMPLEMENTARIOS       0.000000e+00
# 84   5405   IMPUESTO DE RENTA Y COMPLEMENTARIOS       0.000000e+00
# 85   5405  COMERCIO AL POR MAYOR Y AL POR MENOR       0.000000e+00
# 85   5405  COMERCIO AL POR MAYOR Y AL POR MENOR       0.000000e+00
# 86   6135  COMERCIO AL POR MAYOR Y AL POR MENOR       3.685183e+08
#
#     Saldo Finaloct18   Saldo Final
# 0       1.073849e+05  2.661946e+05
# 1       1.445734e+06  1.489734e+06
# 2      -1.105300e+01  7.318712e+04
# ...

# %%
lista_columnas = list(dfa.columns)
lista_columnas[4] = "Saldo Finaldic18"
dfa.columns = lista_columnas

# %%
dfa['Cuenta'] = dfa['Cuenta'].astype(int)

# %%
dff = dfa[dfa['Cuenta'] < 4135]

# %%
dfc = dff.drop(['Saldo Finaloct18'], axis=1)

# %%
esf= dfc.fillna(0)

# %%
esf.sum(axis=0)
# Out:
# Cuenta                                                          101207
# Descripción          CAJABANCOSCUENTAS DE AHORROFONDOSCLIENTESDETER...
# Saldo Final_oct19                                          6307455.171
# Saldo Finaldic18                                           2478090.594
# dtype: object

# %%
esf
# Out:
#     Cuenta                                    Descripción  Saldo Final_oct19  \
# 0     1105                                           CAJA       9.541741e+04
# 1     1110                                         BANCOS       1.685083e+06
# 2     1120                              CUENTAS DE AHORRO       2.364988e+04
# 3     1125                                         FONDOS       9.383680e+04
# 4     1305                                       CLIENTES       8.357217e+07
# 5     1399                     DETERIORO CARTERA CLIENTES      -1.547971e+05
# 6     1390                        DEUDAS DE DIFICIL COBRO       4.658030e+04
# 7     1365                       OTRAS CUENTAS POR COBRAR       5.748948e+04
# 8     1380                                DEUDORES VARIOS       9.728406e+06
# 9     1355  ANTICIPO DE IMPUESTOS Y CONTRIBUCIONES O SALD       1.246891e+07
# 10    1330                              PAGOS ANTICIPADOS       6.857501e+05
# ...

# %%
esf['Saldo Final_oct19'] = esf['Saldo Final_oct19'].astype(float)
esf['Saldo Finaldic18'] = esf['Saldo Finaldic18'].astype(float)

# %%
esf['Anlisis Horizontal'] = esf['Saldo Final_oct19']-esf['Saldo Finaldic18']

# %%
esf
# Out:
#     Cuenta                                    Descripción  Saldo Final_oct19  \
# 0     1105                                           CAJA       9.541741e+04
# 1     1110                                         BANCOS       1.685083e+06
# 2     1120                              CUENTAS DE AHORRO       2.364988e+04
# 3     1125                                         FONDOS       9.383680e+04
# 4     1305                                       CLIENTES       8.357217e+07
# 5     1399                     DETERIORO CARTERA CLIENTES      -1.547971e+05
# 6     1390                        DEUDAS DE DIFICIL COBRO       4.658030e+04
# 7     1365                       OTRAS CUENTAS POR COBRAR       5.748948e+04
# 8     1380                                DEUDORES VARIOS       9.728406e+06
# 9     1355  ANTICIPO DE IMPUESTOS Y CONTRIBUCIONES O SALD       1.246891e+07
# 10    1330                              PAGOS ANTICIPADOS       6.857501e+05
# ...

# %%
dfr = dfa[dfa['Cuenta'] > 3705]

# %%
dft = dfr.drop(['Saldo Finaldic18'], axis=1)

# %%
er= dft.fillna(0)

# %%
er['Anlisis Horizontal'] = er['Saldo Final_oct19']-er['Saldo Finaloct18']

# %%
er['porcentaje'] = er['Anlisis Horizontal']/er['Saldo Finaloct18']

# %%
er
# Out:
#     Cuenta                           Descripción  Saldo Final_oct19  \
# 50    4135         INGRESOS POR COMERCIALIZACION      -4.098444e+08
# 51    4175           DEVOLUCIONES EN VENTAS (DB)       1.185901e+07
# 52    4210                  INGRESOS FINANCIEROS      -7.142561e+06
# 53    4235                INGRESOS POR SERVICIOS      -8.161275e+06
# 54    4240                        OTROS INGRESOS      -1.638010e+04
# 55    4250                        RECUPERACIONES      -1.349364e+05
# 56    4255                       INDEMNIZACIONES      -1.585404e+05
# 57    4295                              DIVERSOS      -5.591707e+03
# 58    5105       OPERACIONALES DE ADMINISTRACION       4.870927e+06
# 59    5110                            HONORARIOS       9.160157e+05
# 60    5115                             IMPUESTOS       2.398359e+05
# 61    5120                        ARRENDAMIENTOS       1.318274e+06
# 62    5125                        CONTRIBUCIONES       1.563804e+04
# ...
